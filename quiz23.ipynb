# %% [markdown]
# <a href="https://colab.research.google.com/github/SagarSitaula1/Data-Visual/blob/main/quiz23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://www.brookings.edu/blog/brookings-now/2019/12/13/charts-of-the-week-tackling-climate-change/

# %% [markdown]
# Above charts is trying to expalin the global emmission by sector that help to cause global warming. As the first glance I think the pie chart looks really good and has lot of data and information on it. The chart is divided into four parts. I really like how they also used number to help us figure out how much ecah sector is helping in global warming.Not only that it also has two subb division of transport and industry with proper label which makes actually sense.By looking at all the elements all the data and information seems correct because of good labels and accurate graphs.

# %% [markdown]
# ![charts2-world-poverty.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# https://www.visualcapitalist.com/chart-end-world-poverty-sight/

# %% [markdown]
# The collection of graph are chart above tries to show how poverty had been sigificantly decreased from 1990 to 2021. At the first glance on the first chart, I got overwhelmed because I can see a lot of information are stacked on one another. The title of the graph tells us about poverty but the information on the graph tells a different story. I can see information about world war II, first computer invented and other bunch of stuff and I had a hard time relating because the graph does very poor job explaining the data and information.on the chart below it shows a chart that has downward graph showing decrease in poverty but I am not convinced the data is correct.
