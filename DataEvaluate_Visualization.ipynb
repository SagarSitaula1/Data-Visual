# %% [markdown]
# <a href="https://colab.research.google.com/github/SagarSitaula1/Data-Visual/blob/main/DataEvaluate_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Plastic Waste Pollution

# %% [markdown]
# Sagar Sitaula
#
# East Central University
#
# Spring 2022
#
# CPSMA 4313
#
# Instructor: Dr. Nicholas Jacob

# %% [markdown]
# >**Abstract:** Bar charts can be visualized using vertical or horizontal bars. Bar charts are best used to compare a single category of data or several.Here we will examine how plastic waste is effecting the world and helping in climate change.

# %% [markdown]
# #INTRODUCTION
#
# Since the development of plastic earlier this century, it has become a popular material used in a wide variety of ways. Today plastic is used to make, or wrap around, many of the items we buy or use. The problem arises when we no longer want these items and we have to dispose off them, particularly the throwaway plastic material used in wrapping or packaging.
#
# Plastics are used because they are easy and cheap to make and they can last a long time. Unfortunately these same useful qualities can make plastic a huge pollution problem. The cheapness means plastic gets discarded easily and its long life means it survives in the environment for long periods where it can do great harm.
#
# Plastic, the wonder material that we use for everything and which pollutes our environment, is perhaps the most harmful of trash dumped by mariners and sea-goers in sea because it does not readily break down in nature. In-fact, the plastic that goes over the side today may still be around in hundreds of years to foul up the fishing gear, boat propellers, and beaches of future generations.

# %%
import requests
import pandas as pa
from bs4 import BeautifulSoup
r = requests.get("https://ourworldindata.org/plastic-pollution")
html_contents = r.text
html_soup = BeautifulSoup(html_contents,"lxml")

# %%
tables = html_soup.find_all('table')
df = pa.read_html(str(tables))[0]
df.head(10)
# Out:
#                      0                                 1
# 0    Particle category  Diameter range(mm = millimetres)
# 1         Nanoplastics               < 0.0001 mm (0.1μm)
# 2  Small microplastics                    0.00001 – 1 mm
# 3  Large microplastics                       1 – 4.75 mm
# 4         Mesoplastics                     4.76 – 200 mm
# 5        Macroplastics                           >200 mm

# %% [markdown]
# I tried to get the table of the first visualization but coulnot manage to pull the rigth dataset. Here I can see the different types of plastic particle category and their diameter ranges.

# %% [markdown]
# #Why Our world in Data and who are they?
#
# I chose this world data as the source of my data visualization because, I believe it is a great source of visualization and meet the requirement of graphical excellence. No doubt the report is updated in a timely manner. Here is the [link text](https://ourworldindata.org/) of the website I used for my visualization, where you can also find more and has current information of the above topic. The world data is a well known media company which has become a good platform to convey news from the variety of topic.Not only news the platform also provides research material on various topic too. They have large amount of data and charts which makes it great place to look for visualization charts.

# %% [markdown]
# [WEFORUM](https://https://www.weforum.org/)
#
# The World Economic Forum (WEF) is an international non-governmental and lobbying organisation from Switzerland. The founded of it is Klaus Schwab and he founded it on 24 January 1971. The main goal of it is to improving the state of the world by engaging business, political, academic, and other leaders of society to shape global, regional, and industry agendas.

# %% [markdown]
# ![bottle waste 2.PNG](data:image/png;base64,...)

# %% [markdown]
# [WEFORUM](https://www.weforum.org/)
#
# The World Economic Forum (WEF) is an international non-governmental and lobbying organisation from Switzerland. The founded of it is Klaus Schwab and he founded it on 24 January 1971. The main goal of it is to improving the state of the world by engaging business, political, academic, and other leaders of society to shape global, regional, and industry agendas.

# %% [markdown]
# Here, the above graph also shows the information about the pathway on how plastic enters the oceans. It includes all the information explicitly. As we can tell both of them is plotted using bar-graph. The use of color, symbol, labels, pictures are done appropriately. I chose this graph because it is informative and story telling.Here on the graph above we can see global primary production of plastic was 270 million tonnes,global plastic waste was 275 million tonnes – it did exceed annual primary production through wastage of plastic from previous years.We can also see how the graph bar indicating the amount of plastic waste created by different industries. On the green bar and yellow bar we can see the most amount of plastic waste compared to the orange and red bar. Here, is the link
# https://ourworldindata.org/plastic-pollution

# %% [markdown]
# ![555.PNG](data:image/png;base64,...)

# %% [markdown]
# Here, On the second chart we can see in what Industries plastic are used most.If we look at the chart we can see plastic are used mostly in the pacakaging industry. Since most of the business offer home delivery the use of plastic has incresed dreastically in the packaging industry.The chart graphical excellence because all the information are easy to read the bar have different color code which make it visually apealling. Rather than clutterign the chart with lot of data the visualization has just the right amount of infomation. By looking at the visualization we can also see the relation of the chart with the first chart.

# %% [markdown]
# **Why should both of the graph be considered as a great visualization? What are the similarities?**
#
# They're both fantastic graphs. I believe they are both excellent visualizations in their own right. Every piece of information is presented in a logical order. It has excellent graphics and is user-friendly. Well, in terms of similarities, I've already stated several times in the previous graph that they are both bar-plots. In fact, the data source for both graphs is the same. They both have the identical x-axis and y-axis labels. The graph's source, as well as the topic, is explicitly noted. The proper unit is labeled on the bar. Furthermore, both graphs perform admirably in terms of excellence."

# %% [markdown]
# **Graphical Excellence of Both Graph**
#
# Graphical excellence is crucial and a great technique to make a critique about the graph. It also gives and idea about what a graph should contain and helps us determine if it is a good graph.Some of the way to evaluate graphical excellence are:
# - A well-designed presentation of substantive data, statistics, and design
# - Difficult topics expressed clearly, precisely, and quickly
# - The most ideas in the shortest amount of time using the least amount of ink in the smallest amount of space

# %% [markdown]
# **Presentation of data in the graph**
#
# The bar-graph is plainly visible while looking at the data. As we can see, the graph is descriptive, and we can determine what is going on in it without having to spend a lot of time looking it up. The graph condenses a lot of information into one graph and presents it in a logical and efficient manner.
#
# I would also like to add the data dynamically presented. As you look through the graph it takes you through the entire system of network polluting the world. With the help of images and numbers the presentation becomes more effective rather than jst plain numbers.

# %% [markdown]
# **The information on the graph**
#
# The graph is the perfect size, and the method used is both logical and ideal. It has all of the information that a good graph should have. Because the graph is nicely created in that amount of space, an audience can utilize it to create a tale. The graph is the right size for inclusion in a newsletter or article. Even if the graph's size is enlarged, I don't believe it will change the graph's appearance or information.

# %% [markdown]
# **Visualization impact on the article**
#
# Well, there there is not that much going on but, tiny detail matters. The represention of the information is different. On the first graph it shows the number of plastic waste that enter the ocean but on the bar chart it also shows the sector creating the number of plastic waste. And on the second graph we have the plastic waste generation by industial sector in 2015. If we look at the first visualization we can see that the industrial sector produces and dumps most amount of plastic in the ocean and by looking at the second graph we can conclude that packaging sector is the most plastic waste producer in the industrial sector. So, with the help of different data informatin provided by the visualization the article became more interesting and informative.

# %% [markdown]
# # Conclusion
#
# The benefits of reducing plastic consumption include, Preventing pollution by lessening the amount of new raw materials used. Saves energy. Reduces greenhouse gas emissions, which contribute towards climate change.
#
# I presented a total of two graphs in this project that depict the same information in various ways. The graph can be used to differentiate different ways of understanding the same data. Data visualization is critical, and using appropriate graphical brilliance makes it crystal evident.

# %% [markdown]
# **References**
#
#
# - https://ourworldindata.org/plastic-pollution
#
# - https://www.weforum.org/agenda/2022/01/plastic-pollution-climate-change-solution/
#
# - https://www.nationalgeographic.com/environment/article/plastic-pollution
#
# - https://www.behance.net/gallery/106936329/Plastic-Waste-Pollution-data-visualisation
#
# - https://www.science.org/doi/10.1126/sciadv.1700782
#
# - https://github.com/nurfnick/Data_Viz/blob/main/21_Graphical_Excellence.ipynb
