# %% [markdown]
# <a href="https://colab.research.google.com/github/SagarSitaula1/Data-Visual/blob/main/Twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in /usr/local/lib/python3.7/dist-packages (1.19.3)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp drive/MyDrive/config.py .

# %%
import config
import twitter
CONSUMER_KEY = config.CONSUMER_KEY
CONSUMER_SECRET = config.CONSUMER_SECRET
OAUTH_TOKEN = config.OAUTH_TOKEN
OAUTH_TOKEN_SECRET = config.OAUTH_TOKEN_SECRET
auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

mathcs_twitter_api = twitter.Twitter(auth=auth)

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = mathcs_twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = mathcs_twitter_api.trends.place(_id=US_WOE_ID)

for i in range(10):
    print(world_trends[0]['trends'][i]['query'])
# Out:
# Maria
# Scooby
# Naiara
# Bruna
# B%C3%A1rbara
# %22O+Arthur%22
# %23jogodadiscordia
# La%C3%ADs
# Juliette
# %22Arthur+Aguiar%22

# %% [markdown]
# Here, I am going to see what the world is taking about one of my favourite show The walking dead(TWD).

# %%
#  Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.
import json


q = '#TWD'

count = 1000

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = mathcs_twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = mathcs_twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print(json.dumps(statuses, indent=4))
# Out:
# Streaming output truncated to the last 5000 lines.
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Mon Feb 07 17:07:46 +0000 2022",
#             "id": 1490734042282557445,
#             "id_str": "1490734042282557445",
#             "text": "lil king ezekiel study cause he kinda served here #TWD https://t.co/21o623IVUe",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "TWD",
#                         "indices": [
#                             50,
#                             54
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1490734037727473671,
#                         "id_str": "1490734037727473671",
#                         "indices": [
#                             55,
#                             78
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                         "url": "https://t.co/21o623IVUe",
#                         "display_url": "pic.twitter.com/21o623IVUe",
#                         "expanded_url": "https://twitter.com/dinnafashh/status/1490734042282557445/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "large": {
#                                 "w": 2048,
#                                 "h": 2048,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 1200,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 680,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1490734037727473671,
#                         "id_str": "1490734037727473671",
#                         "indices": [
#                             55,
#                             78
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                         "url": "https://t.co/21o623IVUe",
#                         "display_url": "pic.twitter.com/21o623IVUe",
#                         "expanded_url": "https://twitter.com/dinnafashh/status/1490734042282557445/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "large": {
#                                 "w": 2048,
#                                 "h": 2048,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 1200,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 680,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1051426880748843008,
#                 "id_str": "1051426880748843008",
#                 "name": "rasco \ud83e\ude90",
#                 "screen_name": "dinnafashh",
#                 "location": "she/her \u26a1\ufe0f",
#                 "description": "20 | blk | sorry if u followed for art lmfao",
#                 "url": "https://t.co/KSdVbdWKWk",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/KSdVbdWKWk",
#                                 "expanded_url": "http://instagram.com/dinnafashh",
#                                 "display_url": "instagram.com/dinnafashh",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 6712,
#                 "friends_count": 1201,
#                 "listed_count": 66,
#                 "created_at": "Sun Oct 14 10:57:57 +0000 2018",
#                 "favourites_count": 143391,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 26750,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1488369623997186050/FuheL6-b_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1488369623997186050/FuheL6-b_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1051426880748843008/1641687177",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 22,
#             "favorite_count": 125,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 22,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Tue Feb 08 00:44:57 +0000 2022",
#         "id": 1490849093589278720,
#         "id_str": "1490849093589278720",
#         "text": "RT @onterrorstreet: This was posted 8 years ago. Feb 7th 2014. The show would have been in Season 4? #TWD https://t.co/A7EFQgvwIL",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "TWD",
#                     "indices": [
#                         101,
#                         105
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "onterrorstreet",
#                     "name": "Forrest Day",
#                     "id": 1393000508655243265,
#                     "id_str": "1393000508655243265",
#                     "indices": [
#                         3,
#                         18
#                     ]
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1490757592523501569,
#                     "id_str": "1490757592523501569",
#                     "indices": [
#                         106,
#                         129
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FLA8IcyUcAECPsm.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FLA8IcyUcAECPsm.jpg",
#                     "url": "https://t.co/A7EFQgvwIL",
#                     "display_url": "pic.twitter.com/A7EFQgvwIL",
#                     "expanded_url": "https://twitter.com/onterrorstreet/status/1490757594276937731/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "medium": {
#                             "w": 750,
#                             "h": 750,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 750,
#                             "h": 750,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 680,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1490757594276937731,
#                     "source_status_id_str": "1490757594276937731",
#                     "source_user_id": 1393000508655243265,
#                     "source_user_id_str": "1393000508655243265"
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1490757592523501569,
#                     "id_str": "1490757592523501569",
#                     "indices": [
#                         106,
#                         129
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FLA8IcyUcAECPsm.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FLA8IcyUcAECPsm.jpg",
#                     "url": "https://t.co/A7EFQgvwIL",
#                     "display_url": "pic.twitter.com/A7EFQgvwIL",
#                     "expanded_url": "https://twitter.com/onterrorstreet/status/1490757594276937731/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "medium": {
#                             "w": 750,
#                             "h": 750,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 750,
#                             "h": 750,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 680,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1490757594276937731,
#                     "source_status_id_str": "1490757594276937731",
#                     "source_user_id": 1393000508655243265,
#                     "source_user_id_str": "1393000508655243265"
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 862907867862634497,
#             "id_str": "862907867862634497",
#             "name": "Denji \ud83d\udc7d\ud83d\udc7b",
#             "screen_name": "__bijuu",
#             "location": "",
#             "description": "anime, manga, & whatever is cool to read i guess. terrible at video games but somehow still play everyday. 23 \ud83c\udf43\ud83d\udd25\ud83d\ude0c",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 28,
#             "friends_count": 308,
#             "listed_count": 0,
#             "created_at": "Fri May 12 05:50:42 +0000 2017",
#             "favourites_count": 14296,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 2434,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "000000",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1482719149369536516/ErwP5Zs5_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1482719149369536516/ErwP5Zs5_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/862907867862634497/1643760226",
#             "profile_link_color": "1B95E0",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "000000",
#             "profile_text_color": "000000",
#             "profile_use_background_image": false,
#             "has_extended_profile": false,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Mon Feb 07 18:41:22 +0000 2022",
#             "id": 1490757594276937731,
#             "id_str": "1490757594276937731",
#             "text": "This was posted 8 years ago. Feb 7th 2014. The show would have been in Season 4? #TWD https://t.co/A7EFQgvwIL",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "TWD",
#                         "indices": [
#                             81,
#                             85
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1490757592523501569,
#                         "id_str": "1490757592523501569",
#                         "indices": [
#                             86,
#                             109
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FLA8IcyUcAECPsm.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FLA8IcyUcAECPsm.jpg",
#                         "url": "https://t.co/A7EFQgvwIL",
#                         "display_url": "pic.twitter.com/A7EFQgvwIL",
#                         "expanded_url": "https://twitter.com/onterrorstreet/status/1490757594276937731/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 750,
#                                 "h": 750,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 750,
#                                 "h": 750,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 680,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1490757592523501569,
#                         "id_str": "1490757592523501569",
#                         "indices": [
#                             86,
#                             109
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FLA8IcyUcAECPsm.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FLA8IcyUcAECPsm.jpg",
#                         "url": "https://t.co/A7EFQgvwIL",
#                         "display_url": "pic.twitter.com/A7EFQgvwIL",
#                         "expanded_url": "https://twitter.com/onterrorstreet/status/1490757594276937731/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 750,
#                                 "h": 750,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 750,
#                                 "h": 750,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 680,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1393000508655243265,
#                 "id_str": "1393000508655243265",
#                 "name": "Forrest Day",
#                 "screen_name": "onterrorstreet",
#                 "location": "",
#                 "description": "MOVIEidol on Youtube\nCo-host of the 'The Forrest Day Podcast' available on Spotify & Youtube |\nAppetiteForTheDead on Twitch",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 1839,
#                 "friends_count": 99,
#                 "listed_count": 4,
#                 "created_at": "Fri May 14 00:30:06 +0000 2021",
#                 "favourites_count": 1115,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 2168,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1405574261998194693/njDZz95f_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1405574261998194693/njDZz95f_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1393000508655243265/1620952693",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 20,
#             "favorite_count": 220,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 20,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Tue Feb 08 00:44:41 +0000 2022",
#         "id": 1490849026412929024,
#         "id_str": "1490849026412929024",
#         "text": "RT @dinnafashh: lil king ezekiel study cause he kinda served here #TWD https://t.co/21o623IVUe",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "TWD",
#                     "indices": [
#                         66,
#                         70
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "dinnafashh",
#                     "name": "rasco \ud83e\ude90",
#                     "id": 1051426880748843008,
#                     "id_str": "1051426880748843008",
#                     "indices": [
#                         3,
#                         14
#                     ]
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1490734037727473671,
#                     "id_str": "1490734037727473671",
#                     "indices": [
#                         71,
#                         94
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                     "url": "https://t.co/21o623IVUe",
#                     "display_url": "pic.twitter.com/21o623IVUe",
#                     "expanded_url": "https://twitter.com/dinnafashh/status/1490734042282557445/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "large": {
#                             "w": 2048,
#                             "h": 2048,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "medium": {
#                             "w": 1200,
#                             "h": 1200,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 680,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1490734042282557445,
#                     "source_status_id_str": "1490734042282557445",
#                     "source_user_id": 1051426880748843008,
#                     "source_user_id_str": "1051426880748843008"
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1490734037727473671,
#                     "id_str": "1490734037727473671",
#                     "indices": [
#                         71,
#                         94
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                     "url": "https://t.co/21o623IVUe",
#                     "display_url": "pic.twitter.com/21o623IVUe",
#                     "expanded_url": "https://twitter.com/dinnafashh/status/1490734042282557445/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "large": {
#                             "w": 2048,
#                             "h": 2048,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "medium": {
#                             "w": 1200,
#                             "h": 1200,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 680,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1490734042282557445,
#                     "source_status_id_str": "1490734042282557445",
#                     "source_user_id": 1051426880748843008,
#                     "source_user_id_str": "1051426880748843008"
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 874725854873608192,
#             "id_str": "874725854873608192",
#             "name": "Maisy | Commissions open!!!",
#             "screen_name": "MarcelaTamara_",
#             "location": "he/him, they/them",
#             "description": "Hi I\u2019m Mette/Maisy! I\u2019m a queer 27yo traditional & digital artist. Eng/Esp/Fra \ud83c\udded\ud83c\uddf9\ud83c\uddf5\ud83c\uddf7\u300aIf under 18 pls dont follow\u300b **no N/F/T**",
#             "url": "https://t.co/PULWMtlyRB",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/PULWMtlyRB",
#                             "expanded_url": "http://marcelatamara.com",
#                             "display_url": "marcelatamara.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 858,
#             "friends_count": 835,
#             "listed_count": 0,
#             "created_at": "Tue Jun 13 20:31:10 +0000 2017",
#             "favourites_count": 121984,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 65578,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "000000",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1477709402501173254/WM12Xe76_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1477709402501173254/WM12Xe76_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/874725854873608192/1641148134",
#             "profile_link_color": "981CEB",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "000000",
#             "profile_text_color": "000000",
#             "profile_use_background_image": false,
#             "has_extended_profile": true,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Mon Feb 07 17:07:46 +0000 2022",
#             "id": 1490734042282557445,
#             "id_str": "1490734042282557445",
#             "text": "lil king ezekiel study cause he kinda served here #TWD https://t.co/21o623IVUe",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "TWD",
#                         "indices": [
#                             50,
#                             54
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1490734037727473671,
#                         "id_str": "1490734037727473671",
#                         "indices": [
#                             55,
#                             78
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                         "url": "https://t.co/21o623IVUe",
#                         "display_url": "pic.twitter.com/21o623IVUe",
#                         "expanded_url": "https://twitter.com/dinnafashh/status/1490734042282557445/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "large": {
#                                 "w": 2048,
#                                 "h": 2048,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 1200,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 680,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1490734037727473671,
#                         "id_str": "1490734037727473671",
#                         "indices": [
#                             55,
#                             78
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                         "url": "https://t.co/21o623IVUe",
#                         "display_url": "pic.twitter.com/21o623IVUe",
#                         "expanded_url": "https://twitter.com/dinnafashh/status/1490734042282557445/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "large": {
#                                 "w": 2048,
#                                 "h": 2048,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 1200,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 680,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1051426880748843008,
#                 "id_str": "1051426880748843008",
#                 "name": "rasco \ud83e\ude90",
#                 "screen_name": "dinnafashh",
#                 "location": "she/her \u26a1\ufe0f",
#                 "description": "20 | blk | sorry if u followed for art lmfao",
#                 "url": "https://t.co/KSdVbdWKWk",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/KSdVbdWKWk",
#                                 "expanded_url": "http://instagram.com/dinnafashh",
#                                 "display_url": "instagram.com/dinnafashh",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 6712,
#                 "friends_count": 1201,
#                 "listed_count": 66,
#                 "created_at": "Sun Oct 14 10:57:57 +0000 2018",
#                 "favourites_count": 143391,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 26750,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1488369623997186050/FuheL6-b_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1488369623997186050/FuheL6-b_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1051426880748843008/1641687177",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 22,
#             "favorite_count": 125,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 22,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Tue Feb 08 00:44:30 +0000 2022",
#         "id": 1490848982486028292,
#         "id_str": "1490848982486028292",
#         "text": "RT @dinnafashh: lil king ezekiel study cause he kinda served here #TWD https://t.co/21o623IVUe",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "TWD",
#                     "indices": [
#                         66,
#                         70
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "dinnafashh",
#                     "name": "rasco \ud83e\ude90",
#                     "id": 1051426880748843008,
#                     "id_str": "1051426880748843008",
#                     "indices": [
#                         3,
#                         14
#                     ]
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1490734037727473671,
#                     "id_str": "1490734037727473671",
#                     "indices": [
#                         71,
#                         94
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                     "url": "https://t.co/21o623IVUe",
#                     "display_url": "pic.twitter.com/21o623IVUe",
#                     "expanded_url": "https://twitter.com/dinnafashh/status/1490734042282557445/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "large": {
#                             "w": 2048,
#                             "h": 2048,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "medium": {
#                             "w": 1200,
#                             "h": 1200,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 680,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1490734042282557445,
#                     "source_status_id_str": "1490734042282557445",
#                     "source_user_id": 1051426880748843008,
#                     "source_user_id_str": "1051426880748843008"
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1490734037727473671,
#                     "id_str": "1490734037727473671",
#                     "indices": [
#                         71,
#                         94
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                     "url": "https://t.co/21o623IVUe",
#                     "display_url": "pic.twitter.com/21o623IVUe",
#                     "expanded_url": "https://twitter.com/dinnafashh/status/1490734042282557445/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "large": {
#                             "w": 2048,
#                             "h": 2048,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "medium": {
#                             "w": 1200,
#                             "h": 1200,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 680,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1490734042282557445,
#                     "source_status_id_str": "1490734042282557445",
#                     "source_user_id": 1051426880748843008,
#                     "source_user_id_str": "1051426880748843008"
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1381374011930710017,
#             "id_str": "1381374011930710017",
#             "name": "\u2606PeachFork\u2606 (The Kitchen)",
#             "screen_name": "T0astMe",
#             "location": "20",
#             "description": "Elias \nHe/Toy\nBlack\nrt heavy + I WILL post OC content with little to no context\neng/esp\nlearning cn",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 43,
#             "friends_count": 257,
#             "listed_count": 1,
#             "created_at": "Sun Apr 11 22:30:32 +0000 2021",
#             "favourites_count": 15190,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 5176,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1478052287037775873/2gnEojhr_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1478052287037775873/2gnEojhr_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1381374011930710017/1636080873",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Mon Feb 07 17:07:46 +0000 2022",
#             "id": 1490734042282557445,
#             "id_str": "1490734042282557445",
#             "text": "lil king ezekiel study cause he kinda served here #TWD https://t.co/21o623IVUe",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "TWD",
#                         "indices": [
#                             50,
#                             54
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1490734037727473671,
#                         "id_str": "1490734037727473671",
#                         "indices": [
#                             55,
#                             78
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FLAmtYVUcAcJ68I.jpg",
#                         "url": "https://t.co/21o623IVUe",
#                         "display_url": "pic.twitter.com/21o623IVUe",
#                         "expanded_url": "https://twitter.com/dinnafashh/status/1490734042282557445/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "large": {
#                                 "w": 2048,
#                                 "h": 2048,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
# ...
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1208178969914290176,
#                 "id_str": "1208178969914290176",
#                 "name": "\u0644\u0624\u064a ((11)) \u0641\u0628\u0631\u0627\u064a\u0631 \u0648\u0644\u0646 \u0627\u0632\u064a\u062f",
#                 "screen_name": "loay_zh",
#                 "location": "",
#                 "description": "(\u062a\u064e\u0648\u064e\u0641\u064e\u0651\u0646\u0650\u064a \u0645\u064f\u0633\u0652\u0644\u0650\u0645\u064b\u0627 \u0648\u064e\u0623\u064e\u0644\u0652\u062d\u0650\u0642\u0652\u0646\u0650\u064a \u0628\u0650\u0627\u0644\u0635\u064e\u0651\u0627\u0644\u0650\u062d\u0650\u064a\u0646\u064e)",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 170,
#                 "friends_count": 1456,
#                 "listed_count": 0,
#                 "created_at": "Sat Dec 21 00:14:56 +0000 2019",
#                 "favourites_count": 242,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": false,
#                 "statuses_count": 45805,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1485252445429276674/zwxb7Cuo_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1485252445429276674/zwxb7Cuo_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1208178969914290176/1636285173",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": true,
#             "quoted_status_id": 1484315718736748550,
#             "quoted_status_id_str": "1484315718736748550",
#             "retweet_count": 0,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": true,
#             "lang": "ar"
#         },
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": true,
#         "lang": "ar"
#     },
#     {
#         "created_at": "Tue Feb 08 00:35:06 +0000 2022",
#         "id": 1490846616030375936,
#         "id_str": "1490846616030375936",
#         "text": "lydia is kinda\u2026annoying?? sorry but\u2026personal opinion #TWD",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "TWD",
#                     "indices": [
#                         53,
#                         57
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1678434535,
#             "id_str": "1678434535",
#             "name": "caswiings\ud83c\udff3\ufe0f\u200d\ud83c\udf08",
#             "screen_name": "ifigotumalik",
#             "location": "London, N.Y, Hogwarts, Firenze",
#             "description": "you changed me, dean...\ud83c\udf08",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 1159,
#             "friends_count": 603,
#             "listed_count": 32,
#             "created_at": "Sat Aug 17 14:46:57 +0000 2013",
#             "favourites_count": 145356,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 178671,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "9AE4E8",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme16/bg.gif",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme16/bg.gif",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1489700821281423368/I6eFufEO_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1489700821281423368/I6eFufEO_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1678434535/1642034611",
#             "profile_link_color": "0084B4",
#             "profile_sidebar_border_color": "BDDCAD",
#             "profile_sidebar_fill_color": "DDFFCC",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 1,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Tue Feb 08 00:34:10 +0000 2022",
#         "id": 1490846382730911744,
#         "id_str": "1490846382730911744",
#         "text": "11\u2705 \u0627\u0644\u0642\u0633\u0645 \u0627\u0644\u0627\u0648\u0644 \n\u0648\u0627\u0644\u0644\u0647 \u064a \u0641\u064a\u0647 \u0628\u0639\u0636 \u0627\u0644\u062d\u0644\u0642\u0627\u062a \u0627\u0646\u0647\u0627 \u062a\u0645\u063a\u062b \u0628\u0627\u0644\u0630\u0627\u062a \u0634\u062e\u0635\u064a\u0629 \u064a\u0648\u062c\u064a\u0646 \u0648\u0627\u0632\u064a\u0643\u064a\u0644 \u0648\u0627\u0644\u0644\u064a \u0645\u0639\u0647\u0645 \u0627\u0644\u063a\u0628\u064a\u0629 \u0630\u064a\u0643 \n+ \u0628\u0648\u0628 \u0646\u0647\u0627\u064a\u062a\u0647 \u0633\u2026 https://t.co/K5CxnOYfMi",
#         "truncated": true,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/K5CxnOYfMi",
#                     "expanded_url": "https://twitter.com/i/web/status/1490846382730911744",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         117,
#                         140
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "ar",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1208178969914290176,
#             "id_str": "1208178969914290176",
#             "name": "\u0644\u0624\u064a ((11)) \u0641\u0628\u0631\u0627\u064a\u0631 \u0648\u0644\u0646 \u0627\u0632\u064a\u062f",
#             "screen_name": "loay_zh",
#             "location": "",
#             "description": "(\u062a\u064e\u0648\u064e\u0641\u064e\u0651\u0646\u0650\u064a \u0645\u064f\u0633\u0652\u0644\u0650\u0645\u064b\u0627 \u0648\u064e\u0623\u064e\u0644\u0652\u062d\u0650\u0642\u0652\u0646\u0650\u064a \u0628\u0650\u0627\u0644\u0635\u064e\u0651\u0627\u0644\u0650\u062d\u0650\u064a\u0646\u064e)",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 170,
#             "friends_count": 1456,
#             "listed_count": 0,
#             "created_at": "Sat Dec 21 00:14:56 +0000 2019",
#             "favourites_count": 242,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 45805,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1485252445429276674/zwxb7Cuo_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1485252445429276674/zwxb7Cuo_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1208178969914290176/1636285173",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": true,
#         "quoted_status_id": 1484315718736748550,
#         "quoted_status_id_str": "1484315718736748550",
#         "quoted_status": {
#             "created_at": "Fri Jan 21 00:03:39 +0000 2022",
#             "id": 1484315718736748550,
#             "id_str": "1484315718736748550",
#             "text": "10 \u2705 \n11 \u23f3 \n#twd https://t.co/VjSqVaWAzC",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "twd",
#                         "indices": [
#                             12,
#                             16
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [
#                     {
#                         "url": "https://t.co/VjSqVaWAzC",
#                         "expanded_url": "https://twitter.com/loay_zh/status/1484288241251631107",
#                         "display_url": "twitter.com/loay_zh/status\u2026",
#                         "indices": [
#                             17,
#                             40
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "ar",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1208178969914290176,
#                 "id_str": "1208178969914290176",
#                 "name": "\u0644\u0624\u064a ((11)) \u0641\u0628\u0631\u0627\u064a\u0631 \u0648\u0644\u0646 \u0627\u0632\u064a\u062f",
#                 "screen_name": "loay_zh",
#                 "location": "",
#                 "description": "(\u062a\u064e\u0648\u064e\u0641\u064e\u0651\u0646\u0650\u064a \u0645\u064f\u0633\u0652\u0644\u0650\u0645\u064b\u0627 \u0648\u064e\u0623\u064e\u0644\u0652\u062d\u0650\u0642\u0652\u0646\u0650\u064a \u0628\u0650\u0627\u0644\u0635\u064e\u0651\u0627\u0644\u0650\u062d\u0650\u064a\u0646\u064e)",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 170,
#                 "friends_count": 1456,
#                 "listed_count": 0,
#                 "created_at": "Sat Dec 21 00:14:56 +0000 2019",
#                 "favourites_count": 242,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": false,
#                 "statuses_count": 45805,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1485252445429276674/zwxb7Cuo_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1485252445429276674/zwxb7Cuo_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1208178969914290176/1636285173",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": true,
#             "quoted_status_id": 1484288241251631107,
#             "quoted_status_id_str": "1484288241251631107",
#             "retweet_count": 0,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": true,
#             "lang": "und"
#         },
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": true,
#         "lang": "ar"
#     }
# ]
